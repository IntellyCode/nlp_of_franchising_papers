# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("/scratch/go76fil/Programs/Python/Paper_Topic_Modelling")
os.getcwd()
# Out:
# '/scratch/go76fil/Programs/Python/Paper_Topic_Modelling'

# %%
import pickle
with open('./output/store/light_preprocessed_pdf_files.pkl', 'rb') as f:
    light_preprocessed_pdf_files, _ = pickle.load(f)

# %%
with open("./output/store/optimal_hyperparams.pkl", "rb") as f:
    params = pickle.load(f)

# %%
print(len(light_preprocessed_pdf_files))
print(params)
# Out:
# 555
# (<hyperopt.base.Trials object at 0x7422cd6b5d60>, {'embedding_model': 'sentence-transformers/paraphrase-MiniLM-L3-v2', 'hdbscan_model': {'min_cluster_size': 29.0, 'min_samples': 13.0}, 'umap_model': {'metric': 'manhattan', 'min_dist': 0.15717970056189712, 'n_components': 2.0, 'n_neighbors': 8.0}})

# %%
from src.bert import BertModel
seed = 42
model = BertModel(light_preprocessed_pdf_files, seed)
topics, probabilities = model.assemble(params[1])
# Out:
# 2025-03-24 17:48:41,698 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# 2025-03-24 17:48:45,974 - BERTopic - Embedding - Completed ✓
# 2025-03-24 17:48:45,974 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-03-24 17:48:46,736 - BERTopic - Dimensionality - Completed ✓
# 2025-03-24 17:48:46,737 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-03-24 17:48:46,748 - BERTopic - Cluster - Completed ✓
# 2025-03-24 17:48:46,751 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-03-24 17:48:55,082 - BERTopic - Representation - Completed ✓

# %%
df = model.topic_model.get_topic_info()
df
# Out:
#    Topic  Count                                               Name  \
# 0     -1    232          -1_muf_csr_transfer mechanisms_noncompete
# 1      0    273                       0_eo_csr_personalization_muf
# 2      1     50  1_trade secret_learning development_constructi...
#
#                                       Representation  \
# 0  [muf, csr, transfer mechanisms, noncompete, so...
# 1  [eo, csr, personalization, muf, innovativeness...
# 2  [trade secret, learning development, construct...
#
#                                  Representative_Docs
# 0  [trust and multi unit ownership in franchising...
# 1  [a cross cultural exploration of franchise ent...
# 2  [the franchise marketing funds piggy bank! a c...

# %%
df.to_excel("./output/bert_topics.xlsx")
