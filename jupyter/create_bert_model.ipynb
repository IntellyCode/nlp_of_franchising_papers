# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("/scratch/go76fil/Programs/Python/Paper_Topic_Modelling")
os.getcwd()
# Out:
# '/scratch/go76fil/Programs/Python/Paper_Topic_Modelling'

# %%
import pickle
with open('./output/store/light_preprocessed_pdf_files.pkl', 'rb') as f:
    light_preprocessed_pdf_files, _ = pickle.load(f)

# %%
with open("./output/store/CDO_100.pkl", "rb") as f:
    params = pickle.load(f)

# %%
print(len(light_preprocessed_pdf_files))
print(params)
# Out:
# 555
# (<hyperopt.base.Trials object at 0x7371f84b33b0>, {'embedding_model': 'sentence-transformers/all-MiniLM-L6-v2', 'hdbscan_model': {'min_cluster_size': 39.0, 'min_samples': 15.0}, 'umap_model': {'metric': 'euclidean', 'min_dist': 0.24800364554968973, 'n_components': 1.0, 'n_neighbors': 4.0}})

# %%
from src.bert import BertModel
seed = 42
model = BertModel(light_preprocessed_pdf_files, seed)
topics, probabilities = model.assemble(params[1])
# Out:
# 2025-03-25 13:40:30,106 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/18 [00:00<?, ?it/s]
# 2025-03-25 13:40:34,890 - BERTopic - Embedding - Completed ✓
# 2025-03-25 13:40:34,891 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-03-25 13:40:41,627 - BERTopic - Dimensionality - Completed ✓
# 2025-03-25 13:40:41,628 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-03-25 13:40:41,639 - BERTopic - Cluster - Completed ✓
# 2025-03-25 13:40:41,642 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-03-25 13:40:49,692 - BERTopic - Representation - Completed ✓

# %%
df = model.topic_model.get_topic_info()
df
# Out:
#    Topic  Count                                               Name  \
# 0     -1    298  -1_csr_supra_supra note_environmental uncertainty
# 1      0    210                          0_muf_suf_brazilian_supra
# 2      1     47         1_learning development_hardness_ei_migrant
#
#                                       Representation  \
# 0  [csr, supra, supra note, environmental uncerta...
# 1  [muf, suf, brazilian, supra, supra note, churc...
# 2  [learning development, hardness, ei, migrant, ...
#
#                                  Representative_Docs
# 0  [franchising lessons in the age of incivility:...
# 1  [an introspective examination of single unit v...
# 2  [who wants to be a franchisee? integrating the...

# %%
df.to_excel("./output/bert_topics.xlsx")
